# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
all_points = xr.load_dataarray(r'C:\Users\vovam\Desktop\rotations\Leeat Keren\data\all_data.nc')

# %% [markdown]
# ## First 7 -CD20; CD4; CD8; CD45; HLA Class II; dsDNA; panCK;
#
# There is no panCK in our dataset so I added panK and also added CD3 as it may be a useful marker (Idan's advice)

# %%
src = r'Z:\vovam\Vova\data\matrices\8_25'


def load_data(src):
    channels_src = 'channels.txt'
    with open(os.path.join(src, channels_src)) as f:
        channels = f.read().splitlines()

    mat = np.loadtxt(os.path.join(src, 'mat.txt')).astype(np.float32)
    mat = (mat / np.linalg.norm(mat, ord=1, axis=0))
    return mat, channels


needed_channels = load_data(src)[1]

# %%
channels_data = all_points.sel(channels = needed_channels)

# %% [markdown]
# ## Turn tensor into matrix of needed shape, remove negatives, and binarise

# %%
channels_mat = np.transpose(channels_data.values, [1, 0, 2, 3])
# channels_mat.shape == (7, 38, 2048, 2048)
print(channels_mat.shape)
channels_mat = channels_mat.reshape((7, -1))
# channels_mat.shape == (7, 38*2048*2048)
print(channels_mat.shape)
channels_mat = channels_mat.clip(min = 0)
channels_mat = 1 * (channels_mat > 0)
# Out:
# (7, 38, 2048, 2048)
# (7, 159383552)

# %% [markdown]
# ## Sum over the columns

# %%
counts_mat = channels_mat.sum(axis = 0)
print(counts_mat.shape)
# Out:
# (159383552,)

# %% [markdown]
# ## Plot results of the counts

# %%
value, counts = np.unique(counts_mat, return_counts=True)
dist = dict(zip(value, counts))
plt.figure(figsize = (20,10))
plt.bar(dist.keys(), dist.values())
plt.ylabel('Counts of pixels')
plt.xlabel('Number of active channels on given pixel across all points')
# Out:
# Text(0.5, 0, 'Number of active channels on given pixel across all points')

# %% [markdown]
# ## Covariance and Correlation matrices of given channels

# %%
cov_mat = np.load(r'Z:\vovam\scripts\covP5.npy')

# %%
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(10, 8))
sns.heatmap(cov_mat, 
            xticklabels=needed_channels,
            yticklabels=needed_channels)
plt.title('Covariance Matrix', fontsize=16);

# %%
corr_mat = np.load(r'Z:\vovam\scripts\corrP5.npy')
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(40, 40))
sns.heatmap(corr_mat, 
            xticklabels=needed_channels,
            yticklabels=needed_channels, annot = True)
plt.title('Correlation Matrix', fontsize=16);

# %%
torch.tensor(np.load(r'Z:\vovam\scripts\corrP5.npy'))
# Out:
# tensor([[ 1.0000e+00, -5.1027e-02, -6.7453e-02, -2.3161e-02, -5.1552e-03,
#           4.0215e-02, -2.6305e-02,  7.5240e-04,  7.8120e-02, -2.8235e-02,
#          -6.3709e-02, -8.3624e-02,  2.0061e-02,  4.8055e-02,  1.6633e-03,
#           4.6956e-03, -1.2796e-01, -1.5580e-01, -9.4374e-02, -1.1227e-01,
#          -3.3535e-02, -3.8407e-02, -1.3285e-02,  1.6745e-02, -1.0211e-01],
#         [-5.1027e-02,  1.0000e+00,  2.2224e-01,  5.2069e-02,  8.4490e-04,
#          -1.4194e-03,  6.1976e-02,  1.7947e-02, -9.7152e-03,  1.0839e-02,
#           4.2954e-02, -1.1642e-01,  2.9227e-01, -9.5238e-02,  3.4436e-01,
#           1.4232e-01,  1.0000e+00,  4.3128e-01,  5.2106e-02,  4.2768e-01],
#         [-1.3285e-02,  1.1442e-01, -3.5396e-03,  2.2607e-01,  2.4669e-04,
#           2.4650e-02, -5.0139e-03,  1.2205e-01,  3.1315e-03,  2.4655e-02,
#           7.0978e-02,  1.9531e-01,  1.6095e-01,  2.5183e-01,  4.5829e-02,
#           2.0899e-02, -7.7024e-02,  1.8629e-01, -6.0263e-02,  2.2352e-01,
#           9.4993e-02,  4.3128e-01,  1.0000e+00,  3.7091e-02,  2.8183e-01],
#         [ 1.6745e-02,  4.1330e-02, -3.3657e-03, -4.4724e-03, -4.5961e-04,
#          -1.3511e-03,  2.4234e-02, -2.2543e-03, -3.1251e-03, -2.7999e-03,
#           3.2653e-02,  7.8332e-03, -2.2197e-03, -2.3246e-03, -1.8861e-03,
#          -4.8240e-04, -1.0608e-02, -2.9675e-03, -1.1764e-02, -1.3411e-03,
#           1.0635e-01,  5.2106e-02,  3.7091e-02,  1.0000e+00,  1.9480e-02],
#         [-1.0211e-01,  2.9710e-01,  1.5957e-01,  2.1164e-01,  5.3068e-03,
#           7.9340e-03,  1.4344e-01,  8.2413e-02, -9.7641e-03,  6.8042e-02,
#           1.1689e-01,  2.4961e-01,  1.4067e-01,  1.6862e-01,  1.6318e-01,
#           5.1193e-02, -1.0880e-01,  2.9246e-01, -1.2634e-01,  4.1226e-01,
#           1.5634e-01,  4.2768e-01,  2.8183e-01,  1.9480e-02,  1.0000e+00]],
#        dtype=torch.float64)

# %%
import torch

# %%
    def corr(x):
        """
        x: [B, C, H, W]
        res: [B, C, C]
        """

        # [B, C, H, W] -> [B, C, H * W]
        x = x.view((x.size(0), x.size(1), -1))

        # estimated covariance
        x = x - x.mean(dim=-1, keepdim=True)
        factor = 1 / (x.shape[-1] - 1)
        
        cov = factor * (x @ x.transpose(-1, -2))
        diagonal = torch.diagonal(cov, dim1=-2, dim2=-1)
        
        return torch.div(cov,diagonal.unsqueeze(1))

# %%
all_points = xr.load_dataarray(r'C:\Users\leeatgen.WISMAIN\Desktop\Vova\all_data.nc').sel(fovs=['Point5'], channels=needed_channels).values.astype(np.float16)

# %%
channels_mat = torch.tensor(all_points).float()

# %%
first_row = np.array(c[0,2,:])
print(first_row)
# Out:
# [ 2.7945910e+01 -1.4134423e+00 -4.9495587e-01 -2.4310390e-02
#  -5.0529360e-04  8.8191656e-03 -2.7753279e-02  3.6218829e-04
#   4.6386156e-02 -1.4329919e-02 -2.7468124e-01 -2.7005976e-01
#   5.0065424e-02  6.4145155e-02  2.3405529e-03  2.2758595e-03
#  -5.0752240e-01 -5.2455068e-01 -2.5967571e-01 -9.2667389e-01
#  -2.4845177e-02 -2.3613235e-01 -3.0505862e-02  3.2019366e-02
#  -1.2060701e+00]

# %%
c
# Out:
# tensor([[[ 2.7946e+01, -1.4134e+00, -4.9496e-01, -2.4310e-02, -5.0529e-04,
#            8.8192e-03, -2.7753e-02,  3.6219e-04,  4.6386e-02, -1.4330e-02,
#            5.4180e-05, -2.4241e-03,  1.4097e-02, -1.5913e-03,  7.4330e-02,
#            1.9643e-02,  2.3197e-02,  5.7829e-03,  5.3915e-03,  4.8953e-02],
#          [-2.3613e-01,  9.5308e-01, -1.4455e-02,  5.4095e-02,  9.2520e-05,
#            6.0223e-04,  5.1033e-03,  1.3164e-02,  1.4121e-05,  4.7163e-03,
#            7.9543e-02,  2.0665e-01,  1.6521e-01,  8.9650e-02,  2.1274e-02,
#            4.5802e-03, -1.0158e-01,  2.1648e-01, -5.7652e-02,  6.2532e-01,
#            2.3197e-02,  1.3526e+00,  2.1788e-01,  2.1920e-02,  1.1113e+00],
#          [-3.0506e-02,  2.6043e-01, -2.1341e-03,  1.9498e-02,  1.9870e-06,
#            4.4418e-04, -4.3466e-04,  4.8278e-03,  1.5279e-04,  1.0282e-03,
#            2.5145e-02,  5.1828e-02,  3.3006e-02,  2.7621e-02,  5.2991e-03,
#            8.3233e-04, -2.5102e-02,  5.1536e-02, -1.3625e-02,  1.5160e-01,
#            5.7829e-03,  2.1788e-01,  1.8868e-01,  5.8277e-03,  2.7352e-01],
#          [ 3.2019e-02,  7.8334e-02, -1.6898e-03, -3.2120e-04, -3.0825e-06,
#           -2.0275e-05,  1.7494e-03, -7.4254e-05, -1.2696e-04, -9.7227e-05,
#            9.6328e-03,  1.7309e-03, -3.7906e-04, -2.1231e-04, -1.8160e-04,
#           -1.6002e-05, -2.8789e-03, -6.8359e-04, -2.2148e-03, -7.5733e-04,
#            5.3915e-03,  2.1920e-02,  5.8277e-03,  1.3083e-01,  1.5743e-02],
#          [-1.2061e+00,  3.4781e+00,  4.9486e-01,  9.3884e-02,  2.1983e-04,
#            7.3537e-04,  6.3958e-02,  1.6767e-02, -2.4503e-03,  1.4595e-02,
#            2.1300e-01,  3.4069e-01,  1.4837e-01,  9.5125e-02,  9.7046e-02,
#            1.0486e-02, -1.8238e-01,  4.1615e-01, -1.4692e-01,  1.4382e+00,
#            4.8953e-02,  1.1113e+00,  2.7352e-01,  1.5743e-02,  4.9917e+00]]])

# %%
(first_row/diagonal[0,2]).max()
# Out:
# tensor(14.5045)

# %%
diagonal
# Out:
# tensor([[2.7946e+01, 2.7456e+01, 1.9267e+00, 3.9422e-02, 3.4376e-04, 1.7210e-03,
#          3.9831e-02, 8.2922e-03, 1.2617e-02, 9.2167e-03, 6.6518e-01, 3.7320e-01,
#          2.2289e-01, 6.3759e-02, 7.0856e-02, 8.4053e-03, 5.6289e-01, 4.0562e-01,
#          2.7092e-01, 2.4379e+00, 1.9643e-02, 1.3526e+00, 1.8868e-01, 1.3083e-01,
#          4.9917e+00]])

# %%
ds = torch.randint(low=0, high=200, size=(36, 8, 1024, 1024)).float()
test = torch.tensor(ds).float()
# Out:
# <ipython-input-661-f86e471afba7>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test = torch.tensor(ds).float()

# %%
for i in range(8):
    plt.subplot(8,1,i+1)
    sns.heatmap(corr(ds)[i,:,:])

# %%
channels_mat.shape
# Out:
# torch.Size([1, 25, 2048, 2048])

# %%
np.transpose(channels_mat, [1, 0,2, 3]).shape
# Out:
# torch.Size([25, 1, 2048, 2048])
