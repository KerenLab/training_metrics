# %%
import xarray as xr
import scipy as sp
from scipy import ndimage
import torch
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import preprocessing
from sklearn.metrics import f1_score as f1
from sklearn.metrics import jaccard_score as jacc
from sklearn.metrics import mean_squared_error as mse
import skimage.io as io
import pandas as pd

# %%
all_data = xr.load_dataarray(r'C:\Users\vovam\Desktop\rotations\Leeat Keren\data\all_data.nc')

# %%
standart_data = torch.load(r'Z:\vovam\Vova\outputs\2021-05-06\06-58-07\x_hat\iter170000_0.23.pt',map_location=torch.device('cpu'))
standart_data = standart_data.detach().numpy().squeeze()

# %%
permut_data = torch.load(r'Z:\vovam\Vova\outputs\2021-05-07\10-11-57\x_hat\iter170000_0.50.pt',map_location=torch.device('cpu'))
permut_data = permut_data.detach().numpy().squeeze()

# %%
newmat_data = torch.load(r'Z:\vovam\Vova\outputs\2021-05-08\16-57-28\x_hat\iter167500_0.54.pt',map_location=torch.device('cpu'))
newmat_data = newmat_data.detach().numpy().squeeze()

# %%
def print_scores(scores, channels, ch_range):
    new_metric = np.zeros([1,ch_range])
    for i, chname in enumerate(channels):
        new_metric[0,i] = scores[0][0][i]/(scores[1][0][i]*100)
        print('For ch {}_{}'.format(i, chname))
        print('The f1 score is {:.2f} rmse is {:.6f} new metric {:.2f} '.format(scores[0][0][i], scores[1][0][i], new_metric[0,i]))
    #plt.scatter(preprocessing.normalize(scores[0]),preprocessing.normalize(new_metric))
    return(new_metric)

# %%
def get_scores(p_true, p_hat, point_name,channels):
    
    ch_range = len(channels)
    f1scores = np.zeros([1,ch_range])
    rmsescores = np.zeros([1,ch_range])
    sum_signal = np.zeros([1,ch_range])
    binary_sum = np.zeros([1,ch_range])
    for i,chname in enumerate(channels):

        true_data = p_true.sel(fovs=[point_name], channels = chname)
        true_data = true_data.values.squeeze().flatten()
        
        
        hat_data = p_hat[i,:,:].squeeze().flatten()
        hat_data = np.rint(hat_data)
        io.imsave(f'permut_experiments/pictures/newmat_{i}_{chname}.tif', hat_data.reshape((2048,2048)), check_contrast=False)

        binary_true = 1 * (true_data > 0)
        binary_hat = 1 *(hat_data > 0)

        f1scores[0,i] = f1(binary_true,binary_hat)
        rmsescores[0,i] = mse(true_data, hat_data, squared = False)/np.linalg.norm(true_data, ord=None, axis=None, keepdims=False)
        sum_signal[0,i] = sum(true_data)
        binary_sum[0,i] = sum(binary_true) 
        
    return(f1scores, rmsescores, sum_signal,binary_sum)

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25\channels.txt') as f:
    ch_list = f.read().split('\n')
    
standart = get_scores(all_data, standart_data,'Point5',ch_list)
print_scores(standart, ch_list,len(ch_list))
# Out:
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000093 new metric 102.88
# For ch 1_Vimentin
# The f1 score is 0.75 rmse is 0.000084 new metric 88.89
# For ch 2_SMA
# The f1 score is 0.94 rmse is 0.000088 new metric 106.85
# For ch 3_CD4
# The f1 score is 0.30 rmse is 0.000818 new metric 3.70
# For ch 4_CD56
# The f1 score is 0.02 rmse is 0.002056 new metric 0.11
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.001535 new metric 0.07
# For ch 6_CD31
# The f1 score is 0.41 rmse is 0.000443 new metric 9.21
# For ch 7_PD1
# The f1 score is 0.12 rmse is 0.001666 new metric 0.71
# For ch 8_Ki67
# The f1 score is 0.10 rmse is 0.001953 new metric 0.53
# For ch 9_CD209
# The f1 score is 0.16 rmse is 0.001159 new metric 1.37
# For ch 10_CD68
# The f1 score is 0.84 rmse is 0.000135 new metric 61.98
# For ch 11_CD11c
# The f1 score is 0.70 rmse is 0.000247 new metric 28.53
# For ch 12_CD8
# The f1 score is 0.50 rmse is 0.000372 new metric 13.33
# For ch 13_CD3
# The f1 score is 0.17 rmse is 0.001191 new metric 1.46
# For ch 14_IDO
# The f1 score is 0.39 rmse is 0.000476 new metric 8.26
# For ch 15_CD20
# The f1 score is 0.14 rmse is 0.000529 new metric 2.55
# For ch 16_Beta catenin
# The f1 score is 0.92 rmse is 0.000158 new metric 58.45
# For ch 17_CD16
# The f1 score is 0.38 rmse is 0.000412 new metric 9.32
# For ch 18_Pan-Keratin
# The f1 score is 0.75 rmse is 0.000270 new metric 27.75
# For ch 19_HLA-DR
# The f1 score is 0.86 rmse is 0.000160 new metric 53.96
# For ch 20_CD11b
# The f1 score is 0.24 rmse is 0.000511 new metric 4.70
# For ch 21_CD45
# The f1 score is 0.85 rmse is 0.000198 new metric 42.72
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000376 new metric 16.84
# For ch 23_MPO
# The f1 score is 0.07 rmse is 0.000762 new metric 0.94
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000166 new metric 52.99
# array([[1.02879844e+02, 8.88912013e+01, 1.06849121e+02, 3.70339870e+00,
#         1.06387124e-01, 6.79123233e-02, 9.21190429e+00, 7.13027708e-01,
#         5.30826000e-01, 1.36888529e+00, 6.19800866e+01, 2.85312736e+01,
#         1.33270603e+01, 1.46211489e+00, 8.26282967e+00, 2.55364324e+00,
#         5.84483911e+01, 9.31992302e+00, 2.77479908e+01, 5.39597937e+01,
#         4.69971122e+00, 4.27206290e+01, 1.68352230e+01, 9.35732087e-01,
#         5.29872973e+01]])

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25permut\channels.txt') as f:
    ch_list = f.read().split('\n')
    
permuted = get_scores(all_data, permut_data,'Point5',ch_list)
print_scores(permuted, ch_list,len(ch_list))
# Out:
# For ch 0_CD11c
# The f1 score is 0.69 rmse is 0.000273 new metric 25.36
# For ch 1_CD68
# The f1 score is 0.48 rmse is 0.000766 new metric 6.27
# For ch 2_dsDNA
# The f1 score is 0.95 rmse is 0.000106 new metric 89.43
# For ch 3_Pan-Keratin
# The f1 score is 0.90 rmse is 0.000160 new metric 56.38
# For ch 4_PD1
# The f1 score is 0.11 rmse is 0.001618 new metric 0.68
# For ch 5_MPO
# The f1 score is 0.12 rmse is 0.000485 new metric 2.53
# For ch 6_CD56
# The f1 score is 0.00 rmse is 0.006157 new metric 0.01
# For ch 7_Ki67
# The f1 score is 0.08 rmse is 0.001457 new metric 0.54
# For ch 8_FoxP3
# The f1 score is 0.02 rmse is 0.003838 new metric 0.06
# For ch 9_SMA
# The f1 score is 0.68 rmse is 0.000112 new metric 60.71
# For ch 10_CD31
# The f1 score is 0.26 rmse is 0.000977 new metric 2.68
# For ch 11_CD209
# The f1 score is 0.10 rmse is 0.001698 new metric 0.56
# For ch 12_IDO
# The f1 score is 0.26 rmse is 0.000452 new metric 5.83
# For ch 13_CD20
# The f1 score is 0.02 rmse is 0.002170 new metric 0.11
# For ch 14_CD45
# The f1 score is 0.65 rmse is 0.000350 new metric 18.55
# For ch 15_CD8
# The f1 score is 0.28 rmse is 0.001454 new metric 1.91
# For ch 16_HLA_Class_1
# The f1 score is 0.98 rmse is 0.000158 new metric 61.96
# For ch 17_Beta catenin
# The f1 score is 0.93 rmse is 0.000150 new metric 61.77
# For ch 18_HLA-DR
# The f1 score is 0.69 rmse is 0.000327 new metric 21.18
# For ch 19_CD11b
# The f1 score is 0.27 rmse is 0.000524 new metric 5.18
# For ch 20_CD45RO
# The f1 score is 0.63 rmse is 0.000343 new metric 18.31
# For ch 21_CD4
# The f1 score is 0.37 rmse is 0.000453 new metric 8.23
# For ch 22_Vimentin
# The f1 score is 0.92 rmse is 0.000139 new metric 66.07
# For ch 23_CD3
# The f1 score is 0.13 rmse is 0.000485 new metric 2.71
# For ch 24_CD16
# The f1 score is 0.72 rmse is 0.000310 new metric 23.31
# array([[2.53631450e+01, 6.26856267e+00, 8.94344099e+01, 5.63786360e+01,
#         6.81574550e-01, 2.52840136e+00, 6.34651109e-03, 5.42209488e-01,
#         6.39046245e-02, 6.07145792e+01, 2.67624983e+00, 5.63230861e-01,
#         5.83271129e+00, 1.08163480e-01, 1.85513766e+01, 1.91012761e+00,
#         6.19587795e+01, 6.17692347e+01, 2.11791820e+01, 5.17751041e+00,
#         1.83146540e+01, 8.23126363e+00, 6.60713437e+01, 2.70702416e+00,
#         2.33132774e+01]])

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25new\channels.txt') as f:
    ch_list = f.read().split('\n')
    
newmat = get_scores(all_data, newmat_data,'Point5',ch_list)
print_scores(newmat, ch_list,len(ch_list))
# Out:
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000072 new metric 132.13
# For ch 1_Vimentin
# The f1 score is 0.97 rmse is 0.000174 new metric 55.86
# For ch 2_SMA
# The f1 score is 0.29 rmse is 0.000463 new metric 6.27
# For ch 3_CD4
# The f1 score is 0.12 rmse is 0.001015 new metric 1.22
# For ch 4_CD56
# The f1 score is 0.00 rmse is 0.015818 new metric 0.00
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.006721 new metric 0.02
# For ch 6_CD31
# The f1 score is 0.17 rmse is 0.001460 new metric 1.17
# For ch 7_PD1
# The f1 score is 0.23 rmse is 0.000482 new metric 4.70
# For ch 8_Ki67
# The f1 score is 0.32 rmse is 0.000704 new metric 4.52
# For ch 9_CD209
# The f1 score is 0.19 rmse is 0.000768 new metric 2.53
# For ch 10_CD68
# The f1 score is 0.43 rmse is 0.000657 new metric 6.59
# For ch 11_CD11c
# The f1 score is 0.49 rmse is 0.000442 new metric 11.01
# For ch 12_CD8
# The f1 score is 0.59 rmse is 0.000323 new metric 18.23
# For ch 13_CD3
# The f1 score is 0.39 rmse is 0.000424 new metric 9.19
# For ch 14_IDO
# The f1 score is 0.29 rmse is 0.000517 new metric 5.62
# For ch 15_CD20
# The f1 score is 0.03 rmse is 0.001969 new metric 0.13
# For ch 16_Beta catenin
# The f1 score is 0.79 rmse is 0.000235 new metric 33.43
# For ch 17_CD16
# The f1 score is 0.50 rmse is 0.000371 new metric 13.46
# For ch 18_Pan-Keratin
# The f1 score is 0.82 rmse is 0.000228 new metric 35.94
# For ch 19_HLA-DR
# The f1 score is 0.70 rmse is 0.000275 new metric 25.53
# For ch 20_CD11b
# The f1 score is 0.13 rmse is 0.001656 new metric 0.81
# For ch 21_CD45
# The f1 score is 0.73 rmse is 0.000279 new metric 26.22
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000391 new metric 16.01
# For ch 23_MPO
# The f1 score is 0.12 rmse is 0.000462 new metric 2.66
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000223 new metric 39.62
# array([[1.32125674e+02, 5.58570480e+01, 6.27250056e+00, 1.21638964e+00,
#         9.74506247e-04, 1.73854796e-02, 1.16927435e+00, 4.69545169e+00,
#         4.52406021e+00, 2.53055416e+00, 6.59062519e+00, 1.10124854e+01,
#         1.82279167e+01, 9.19241679e+00, 5.62317097e+00, 1.34325863e-01,
#         3.34292370e+01, 1.34597740e+01, 3.59410458e+01, 2.55331268e+01,
#         8.11442358e-01, 2.62156215e+01, 1.60145404e+01, 2.65609454e+00,
#         3.96222816e+01]])

# %%
print(np.mean(print_scores(newmat, ch_list,len(ch_list))))
print(np.mean(print_scores(permuted, ch_list,len(ch_list))))
print(np.mean(print_scores(standart, ch_list,len(ch_list))))
# Out:
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000072 new metric 132.13
# For ch 1_Vimentin
# The f1 score is 0.97 rmse is 0.000174 new metric 55.86
# For ch 2_SMA
# The f1 score is 0.29 rmse is 0.000463 new metric 6.27
# For ch 3_CD4
# The f1 score is 0.12 rmse is 0.001015 new metric 1.22
# For ch 4_CD56
# The f1 score is 0.00 rmse is 0.015818 new metric 0.00
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.006721 new metric 0.02
# For ch 6_CD31
# The f1 score is 0.17 rmse is 0.001460 new metric 1.17
# For ch 7_PD1
# The f1 score is 0.23 rmse is 0.000482 new metric 4.70
# For ch 8_Ki67
# The f1 score is 0.32 rmse is 0.000704 new metric 4.52
# For ch 9_CD209
# The f1 score is 0.19 rmse is 0.000768 new metric 2.53
# For ch 10_CD68
# The f1 score is 0.43 rmse is 0.000657 new metric 6.59
# For ch 11_CD11c
# The f1 score is 0.49 rmse is 0.000442 new metric 11.01
# For ch 12_CD8
# The f1 score is 0.59 rmse is 0.000323 new metric 18.23
# For ch 13_CD3
# The f1 score is 0.39 rmse is 0.000424 new metric 9.19
# For ch 14_IDO
# The f1 score is 0.29 rmse is 0.000517 new metric 5.62
# For ch 15_CD20
# The f1 score is 0.03 rmse is 0.001969 new metric 0.13
# For ch 16_Beta catenin
# The f1 score is 0.79 rmse is 0.000235 new metric 33.43
# For ch 17_CD16
# The f1 score is 0.50 rmse is 0.000371 new metric 13.46
# For ch 18_Pan-Keratin
# The f1 score is 0.82 rmse is 0.000228 new metric 35.94
# For ch 19_HLA-DR
# The f1 score is 0.70 rmse is 0.000275 new metric 25.53
# For ch 20_CD11b
# The f1 score is 0.13 rmse is 0.001656 new metric 0.81
# For ch 21_CD45
# The f1 score is 0.73 rmse is 0.000279 new metric 26.22
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000391 new metric 16.01
# For ch 23_MPO
# The f1 score is 0.12 rmse is 0.000462 new metric 2.66
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000223 new metric 39.62
# 18.11493670944828
# For ch 0_dsDNA
# The f1 score is 0.69 rmse is 0.000273 new metric 25.36
# For ch 1_Vimentin
# The f1 score is 0.48 rmse is 0.000766 new metric 6.27
# For ch 2_SMA
# The f1 score is 0.95 rmse is 0.000106 new metric 89.43
# For ch 3_CD4
# The f1 score is 0.90 rmse is 0.000160 new metric 56.38
# For ch 4_CD56
# The f1 score is 0.11 rmse is 0.001618 new metric 0.68
# For ch 5_FoxP3
# The f1 score is 0.12 rmse is 0.000485 new metric 2.53
# For ch 6_CD31
# The f1 score is 0.00 rmse is 0.006157 new metric 0.01
# For ch 7_PD1
# The f1 score is 0.08 rmse is 0.001457 new metric 0.54
# For ch 8_Ki67
# The f1 score is 0.02 rmse is 0.003838 new metric 0.06
# For ch 9_CD209
# The f1 score is 0.68 rmse is 0.000112 new metric 60.71
# For ch 10_CD68
# The f1 score is 0.26 rmse is 0.000977 new metric 2.68
# For ch 11_CD11c
# The f1 score is 0.10 rmse is 0.001698 new metric 0.56
# For ch 12_CD8
# The f1 score is 0.26 rmse is 0.000452 new metric 5.83
# For ch 13_CD3
# The f1 score is 0.02 rmse is 0.002170 new metric 0.11
# For ch 14_IDO
# The f1 score is 0.65 rmse is 0.000350 new metric 18.55
# For ch 15_CD20
# The f1 score is 0.28 rmse is 0.001454 new metric 1.91
# For ch 16_Beta catenin
# The f1 score is 0.98 rmse is 0.000158 new metric 61.96
# For ch 17_CD16
# The f1 score is 0.93 rmse is 0.000150 new metric 61.77
# For ch 18_Pan-Keratin
# The f1 score is 0.69 rmse is 0.000327 new metric 21.18
# For ch 19_HLA-DR
# The f1 score is 0.27 rmse is 0.000524 new metric 5.18
# For ch 20_CD11b
# The f1 score is 0.63 rmse is 0.000343 new metric 18.31
# For ch 21_CD45
# The f1 score is 0.37 rmse is 0.000453 new metric 8.23
# For ch 22_CD45RO
# The f1 score is 0.92 rmse is 0.000139 new metric 66.07
# For ch 23_MPO
# The f1 score is 0.13 rmse is 0.000485 new metric 2.71
# For ch 24_HLA_Class_1
# The f1 score is 0.72 rmse is 0.000310 new metric 23.31
# 21.613835946988775
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000093 new metric 102.88
# For ch 1_Vimentin
# The f1 score is 0.75 rmse is 0.000084 new metric 88.89
# For ch 2_SMA
# The f1 score is 0.94 rmse is 0.000088 new metric 106.85
# For ch 3_CD4
# The f1 score is 0.30 rmse is 0.000818 new metric 3.70
# For ch 4_CD56
# The f1 score is 0.02 rmse is 0.002056 new metric 0.11
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.001535 new metric 0.07
# For ch 6_CD31
# The f1 score is 0.41 rmse is 0.000443 new metric 9.21
# For ch 7_PD1
# The f1 score is 0.12 rmse is 0.001666 new metric 0.71
# For ch 8_Ki67
# The f1 score is 0.10 rmse is 0.001953 new metric 0.53
# For ch 9_CD209
# The f1 score is 0.16 rmse is 0.001159 new metric 1.37
# For ch 10_CD68
# The f1 score is 0.84 rmse is 0.000135 new metric 61.98
# For ch 11_CD11c
# The f1 score is 0.70 rmse is 0.000247 new metric 28.53
# For ch 12_CD8
# The f1 score is 0.50 rmse is 0.000372 new metric 13.33
# For ch 13_CD3
# The f1 score is 0.17 rmse is 0.001191 new metric 1.46
# For ch 14_IDO
# The f1 score is 0.39 rmse is 0.000476 new metric 8.26
# For ch 15_CD20
# The f1 score is 0.14 rmse is 0.000529 new metric 2.55
# For ch 16_Beta catenin
# The f1 score is 0.92 rmse is 0.000158 new metric 58.45
# For ch 17_CD16
# The f1 score is 0.38 rmse is 0.000412 new metric 9.32
# For ch 18_Pan-Keratin
# The f1 score is 0.75 rmse is 0.000270 new metric 27.75
# For ch 19_HLA-DR
# The f1 score is 0.86 rmse is 0.000160 new metric 53.96
# For ch 20_CD11b
# The f1 score is 0.24 rmse is 0.000511 new metric 4.70
# For ch 21_CD45
# The f1 score is 0.85 rmse is 0.000198 new metric 42.72
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000376 new metric 16.84
# For ch 23_MPO
# The f1 score is 0.07 rmse is 0.000762 new metric 0.94
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000166 new metric 52.99
# 27.923768280117084

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25\channels.txt') as f:
    ch_list = f.read().split('\n')
scores_df = pd.DataFrame({'StandartF1':standart[0][0],'StandartRMSE':standart[1][0]
                          ,'NewMatrixF1':newmat[0][0], 'NewMatrixRMSE':newmat[1][0]}, index = ch_list)

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25permut\channels.txt') as f:
    ch_list = f.read().split('\n')
for i,name in enumerate(ch_list):
    scores_df.loc[name,'PermutedF1'] = permuted[0][0][i]
    scores_df.loc[name, 'PermutedRMSE'] = permuted[1][0][i]

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25\channels.txt') as f:
    ch_list = f.read().split('\n')
new_metric = pd.DataFrame({'Standart':print_scores(standart, ch_list,len(ch_list))[0],
                          'NewMat':print_scores(newmat, ch_list,len(ch_list))[0]
                          }, index = ch_list)
# Out:
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000093 new metric 102.88
# For ch 1_Vimentin
# The f1 score is 0.75 rmse is 0.000084 new metric 88.89
# For ch 2_SMA
# The f1 score is 0.94 rmse is 0.000088 new metric 106.85
# For ch 3_CD4
# The f1 score is 0.30 rmse is 0.000818 new metric 3.70
# For ch 4_CD56
# The f1 score is 0.02 rmse is 0.002056 new metric 0.11
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.001535 new metric 0.07
# For ch 6_CD31
# The f1 score is 0.41 rmse is 0.000443 new metric 9.21
# For ch 7_PD1
# The f1 score is 0.12 rmse is 0.001666 new metric 0.71
# For ch 8_Ki67
# The f1 score is 0.10 rmse is 0.001953 new metric 0.53
# For ch 9_CD209
# The f1 score is 0.16 rmse is 0.001159 new metric 1.37
# For ch 10_CD68
# The f1 score is 0.84 rmse is 0.000135 new metric 61.98
# For ch 11_CD11c
# The f1 score is 0.70 rmse is 0.000247 new metric 28.53
# For ch 12_CD8
# The f1 score is 0.50 rmse is 0.000372 new metric 13.33
# For ch 13_CD3
# The f1 score is 0.17 rmse is 0.001191 new metric 1.46
# For ch 14_IDO
# The f1 score is 0.39 rmse is 0.000476 new metric 8.26
# For ch 15_CD20
# The f1 score is 0.14 rmse is 0.000529 new metric 2.55
# For ch 16_Beta catenin
# The f1 score is 0.92 rmse is 0.000158 new metric 58.45
# For ch 17_CD16
# The f1 score is 0.38 rmse is 0.000412 new metric 9.32
# For ch 18_Pan-Keratin
# The f1 score is 0.75 rmse is 0.000270 new metric 27.75
# For ch 19_HLA-DR
# The f1 score is 0.86 rmse is 0.000160 new metric 53.96
# For ch 20_CD11b
# The f1 score is 0.24 rmse is 0.000511 new metric 4.70
# For ch 21_CD45
# The f1 score is 0.85 rmse is 0.000198 new metric 42.72
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000376 new metric 16.84
# For ch 23_MPO
# The f1 score is 0.07 rmse is 0.000762 new metric 0.94
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000166 new metric 52.99
# For ch 0_dsDNA
# The f1 score is 0.95 rmse is 0.000072 new metric 132.13
# For ch 1_Vimentin
# The f1 score is 0.97 rmse is 0.000174 new metric 55.86
# For ch 2_SMA
# The f1 score is 0.29 rmse is 0.000463 new metric 6.27
# For ch 3_CD4
# The f1 score is 0.12 rmse is 0.001015 new metric 1.22
# For ch 4_CD56
# The f1 score is 0.00 rmse is 0.015818 new metric 0.00
# For ch 5_FoxP3
# The f1 score is 0.01 rmse is 0.006721 new metric 0.02
# For ch 6_CD31
# The f1 score is 0.17 rmse is 0.001460 new metric 1.17
# For ch 7_PD1
# The f1 score is 0.23 rmse is 0.000482 new metric 4.70
# For ch 8_Ki67
# The f1 score is 0.32 rmse is 0.000704 new metric 4.52
# For ch 9_CD209
# The f1 score is 0.19 rmse is 0.000768 new metric 2.53
# For ch 10_CD68
# The f1 score is 0.43 rmse is 0.000657 new metric 6.59
# For ch 11_CD11c
# The f1 score is 0.49 rmse is 0.000442 new metric 11.01
# For ch 12_CD8
# The f1 score is 0.59 rmse is 0.000323 new metric 18.23
# For ch 13_CD3
# The f1 score is 0.39 rmse is 0.000424 new metric 9.19
# For ch 14_IDO
# The f1 score is 0.29 rmse is 0.000517 new metric 5.62
# For ch 15_CD20
# The f1 score is 0.03 rmse is 0.001969 new metric 0.13
# For ch 16_Beta catenin
# The f1 score is 0.79 rmse is 0.000235 new metric 33.43
# For ch 17_CD16
# The f1 score is 0.50 rmse is 0.000371 new metric 13.46
# For ch 18_Pan-Keratin
# The f1 score is 0.82 rmse is 0.000228 new metric 35.94
# For ch 19_HLA-DR
# The f1 score is 0.70 rmse is 0.000275 new metric 25.53
# For ch 20_CD11b
# The f1 score is 0.13 rmse is 0.001656 new metric 0.81
# For ch 21_CD45
# The f1 score is 0.73 rmse is 0.000279 new metric 26.22
# For ch 22_CD45RO
# The f1 score is 0.63 rmse is 0.000391 new metric 16.01
# For ch 23_MPO
# The f1 score is 0.12 rmse is 0.000462 new metric 2.66
# For ch 24_HLA_Class_1
# The f1 score is 0.88 rmse is 0.000223 new metric 39.62

# %%
with open(r'Z:\vovam\Vova\data\matrices\8_25permut\channels.txt') as f:
    ch_list = f.read().split('\n')
newmetric = print_scores(permuted, ch_list,len(ch_list))[0]
for i,name in enumerate(ch_list):
    new_metric.loc[name,'Permuted'] = newmetric[i]
# Out:
# For ch 0_CD11c
# The f1 score is 0.69 rmse is 0.000273 new metric 25.36
# For ch 1_CD68
# The f1 score is 0.48 rmse is 0.000766 new metric 6.27
# For ch 2_dsDNA
# The f1 score is 0.95 rmse is 0.000106 new metric 89.43
# For ch 3_Pan-Keratin
# The f1 score is 0.90 rmse is 0.000160 new metric 56.38
# For ch 4_PD1
# The f1 score is 0.11 rmse is 0.001618 new metric 0.68
# For ch 5_MPO
# The f1 score is 0.12 rmse is 0.000485 new metric 2.53
# For ch 6_CD56
# The f1 score is 0.00 rmse is 0.006157 new metric 0.01
# For ch 7_Ki67
# The f1 score is 0.08 rmse is 0.001457 new metric 0.54
# For ch 8_FoxP3
# The f1 score is 0.02 rmse is 0.003838 new metric 0.06
# For ch 9_SMA
# The f1 score is 0.68 rmse is 0.000112 new metric 60.71
# For ch 10_CD31
# The f1 score is 0.26 rmse is 0.000977 new metric 2.68
# For ch 11_CD209
# The f1 score is 0.10 rmse is 0.001698 new metric 0.56
# For ch 12_IDO
# The f1 score is 0.26 rmse is 0.000452 new metric 5.83
# For ch 13_CD20
# The f1 score is 0.02 rmse is 0.002170 new metric 0.11
# For ch 14_CD45
# The f1 score is 0.65 rmse is 0.000350 new metric 18.55
# For ch 15_CD8
# The f1 score is 0.28 rmse is 0.001454 new metric 1.91
# For ch 16_HLA_Class_1
# The f1 score is 0.98 rmse is 0.000158 new metric 61.96
# For ch 17_Beta catenin
# The f1 score is 0.93 rmse is 0.000150 new metric 61.77
# For ch 18_HLA-DR
# The f1 score is 0.69 rmse is 0.000327 new metric 21.18
# For ch 19_CD11b
# The f1 score is 0.27 rmse is 0.000524 new metric 5.18
# For ch 20_CD45RO
# The f1 score is 0.63 rmse is 0.000343 new metric 18.31
# For ch 21_CD4
# The f1 score is 0.37 rmse is 0.000453 new metric 8.23
# For ch 22_Vimentin
# The f1 score is 0.92 rmse is 0.000139 new metric 66.07
# For ch 23_CD3
# The f1 score is 0.13 rmse is 0.000485 new metric 2.71
# For ch 24_CD16
# The f1 score is 0.72 rmse is 0.000310 new metric 23.31

# %%
scores_df
# Out:
#               StandartF1  StandartRMSE  NewMatrixF1  NewMatrixRMSE  \
# dsDNA           0.953369      0.000093     0.949655       0.000072
# Vimentin        0.746753      0.000084     0.970313       0.000174
# SMA             0.937510      0.000088     0.290559       0.000463
# CD4             0.303098      0.000818     0.123472       0.001015
# CD56            0.021869      0.002056     0.001541       0.015818
# FoxP3           0.010422      0.001535     0.011686       0.006721
# CD31            0.407812      0.000443     0.170716       0.001460
# PD1             0.118776      0.001666     0.226233       0.000482
# Ki67            0.103668      0.001953     0.318524       0.000704
# CD209           0.158710      0.001159     0.194447       0.000768
# CD68            0.838393      0.000135     0.433014       0.000657
# CD11c           0.704182      0.000247     0.486249       0.000442
# CD8             0.495870      0.000372     0.588175       0.000323
# CD3             0.174152      0.001191     0.389710       0.000424
# IDO             0.392906      0.000476     0.290849       0.000517
# CD20            0.135087      0.000529     0.026445       0.001969
# Beta catenin    0.920893      0.000158     0.787131       0.000235
# CD16            0.384344      0.000412     0.499676       0.000371
# Pan-Keratin     0.749055      0.000270     0.818447       0.000228
# HLA-DR          0.864692      0.000160     0.701539       0.000275
# CD11b           0.240200      0.000511     0.134352       0.001656
# CD45            0.846666      0.000198     0.732394       0.000279
# CD45RO          0.633344      0.000376     0.626345       0.000391
# MPO             0.071276      0.000762     0.122723       0.000462
# HLA_Class_1     0.879760      0.000166     0.881799       0.000223
#
#               PermutedF1  PermutedRMSE
# dsDNA           0.948692      0.000106
# Vimentin        0.918503      0.000139
# SMA             0.677620      0.000112
# CD4             0.373244      0.000453
# CD56            0.003908      0.006157
# FoxP3           0.024526      0.003838
# CD31            0.261458      0.000977
# PD1             0.110280      0.001618
# Ki67            0.079005      0.001457
# CD209           0.095616      0.001698
# CD68            0.480042      0.000766
# CD11c           0.691590      0.000273
# CD8             0.277681      0.001454
# CD3             0.131379      0.000485
# IDO             0.263557      0.000452
# CD20            0.023467      0.002170
# Beta catenin    0.926906      0.000150
# CD16            0.723524      0.000310
# Pan-Keratin     0.901833      0.000160
# HLA-DR          0.692134      0.000327
# CD11b           0.271112      0.000524
# CD45            0.649694      0.000350
# CD45RO          0.627660      0.000343
# MPO             0.122701      0.000485
# HLA_Class_1     0.978675      0.000158

# %%
print(np.mean(standart[0]), np.std(standart[0]))
print(np.mean(permuted[0]), np.std(permuted[0]))
print(np.mean(newmat[0]), np.std(newmat[0]))
# Out:
# 0.48371225611559915 0.3293463231780083
# 0.45019229578977443 0.33360886808455215
# 0.4310397520165097 0.30302351474987854

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(scores_df['StandartF1'],scores_df['NewMatrixF1'],scores_df['PermutedF1'])
print(fvalue, pvalue)
# Out:
# 0.16424813397402346 0.8488484752769904
